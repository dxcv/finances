# %%
import sys
sys.path.append(r'C:\\Users\\Pedro\\Dropbox\\repository\\projects\\finances.git\\finances')
# %matplotlib inline

# %%
import os
import numpy as np
import pandas as pd
import pyfolio as pf
# Out:
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# C:\Anaconda3\envs\finance\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
from finances.portfolio.portfolio import PortFolio

# %%
btc_df = get_btc_price()
# Out:
# Loaded BCHARTS/KRAKENUSD from cache
# Loaded BCHARTS/COINBASEUSD from cache
# Loaded BCHARTS/BITSTAMPUSD from cache
# Loaded BCHARTS/ITBITUSD from cache

# %%
def cal_returns(array):
    return array[-1]/array[0]-1

btc_df_returns = btc_df.dropna().rolling(window=2).apply(cal_returns)

# %%
btc_rets = btc_df_returns[-365:].dropna()
btc_rets.plot()

# %%
#pf.create_returns_tear_sheet(btc_rets, benchmark_rets=btc_rets, live_start_date=btc_rets.index[-30])

# %%
pf.create_bayesian_tear_sheet(btc_rets, benchmark_rets=btc_rets, live_start_date=btc_rets.index[-30])
# Out:
# Running T model
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████████████████████████████████████████████████████████████████████████| 2500/2500 [17:38<00:00,  2.36it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:00<00:00, 2889.81it/s]
# Finished T model (required 1060.75 seconds).
#
# Running BEST model
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|██████████████████████████████████████████████████████████████████████████████| 2500/2500 [27:45<00:00,  1.50it/s]C:\Anaconda3\envs\finance\lib\site-packages\pymc3\step_methods\hmc\nuts.py:451: UserWarning: The acceptance probability in chain 0 does not match the target. It is 0.885337080456, but should be close to 0.8. Try to increase the number of tuning steps.
#   % (self._chain_id, mean_accept, target_accept))
# Finished BEST model (required 1667.23 seconds).
#
# Finished plotting Bayesian cone (required 0.65 seconds).
#
# Finished plotting BEST results (required 1.26 seconds).
#
# Finished computing Bayesian predictions (required 0.20 seconds).
#
# Finished plotting Bayesian VaRs estimate (required 0.10 seconds).
#
# Running alpha beta model
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# 100%|████████████████████████████████████████████████████████████████████████████| 2500/2500 [1:05:21<00:00,  1.57s/it]C:\Anaconda3\envs\finance\lib\site-packages\pymc3\step_methods\hmc\nuts.py:451: UserWarning: The acceptance probability in chain 0 does not match the target. It is 0.0677743509012, but should be close to 0.8. Try to increase the number of tuning steps.
#   % (self._chain_id, mean_accept, target_accept))
# C:\Anaconda3\envs\finance\lib\site-packages\pymc3\step_methods\hmc\nuts.py:467: UserWarning: Chain 0 contains 502 diverging samples after tuning. If increasing `target_accept` does not help try to reparameterize.
#   % (self._chain_id, n_diverging))
# Finished running alpha beta model (required 3923.44 seconds).
#
# Finished plotting alpha beta model (required 0.14 seconds).
#
# Total runtime was 6653.76 seconds.
