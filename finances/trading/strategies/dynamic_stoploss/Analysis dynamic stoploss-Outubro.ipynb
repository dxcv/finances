# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import pylab as plt

import portfolioopt as pfopt
from scipy.stats import norm

import seaborn as sns
import os

import sys
sys.path.append('C:\\projects\\finances.git')

from finances.market import market_data as mkt_data

data_path = 'C:\\projects\\finances.git\\finances\\trading\\strategies\\dynamic_stoploss\\data'
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xb
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xb
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xb
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xb

# %%
def sharpe(data):
    return abs(data[data>=0].sum())/abs(data[data<0].sum())
    #return data.mean()/data.std()

# %% [markdown]
# # BTC

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_BTC_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='12H'].boxplot(
    column='strategy',
    by=['period','pct_gap', 'min_gain'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period', 'pct_gap', 'min_gain']).agg(sharpe)

# %%
fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# ### Best performance:
# * Period: 8H
# * Pct Gap: 0.04
# * Min gain: 0.02

# %% [markdown]
# # ETH

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_ETH_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='12H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

# %%
fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# #### Best performance:
# * Period: 4H
# * pct_gap = 0.035
# * minimum gain = 0.0475

# %% [markdown]
# # LTC

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_LTC_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='12H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# #### Best performance:
# * Period: 4H
# * pct_gap = 0.025
# * minimum gain = 0.040

# %% [markdown]
# # XRP

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_XRP_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='12H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# **Best configuration:**
#
# * Period: 8H
#
# * Pct Gap: 0.035
#
# * Minimum Gain: 0.025

# %% [markdown]
# # BCH

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_BCH_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='8H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# **Best configuration:**
#
# * Period: 8H
#
# * Pct Gap: 0.025
#
# * Minimum Gain: 0.03

# %% [markdown]
# # Stellar

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_XLM_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='12H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# # Cardano

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_ADA_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='12H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# # TRON

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_TRX_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='12H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# # IOTA

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_IOTA_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='8H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-04fee042927d> in <module>()
# ----> 1 df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_IOTA_Outubro.csv'))
#       2
#       3 fig, ax = plt.subplots(1,1, figsize=(20,10))
#       4
#       5 df[df['period']=='8H'].boxplot(
#
# NameError: name 'pd' is not defined

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# # NEO

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_NEO_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='8H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# # XMR

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_XMR_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='8H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)

# %% [markdown]
# # DASH

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_DASH_Outubro.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='8H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['1H', '2H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n], legend=(n<1))
    ax[n].set_title(period)
