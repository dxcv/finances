# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import pylab as plt

import portfolioopt as pfopt
from scipy.stats import norm

import seaborn as sns
import os


import sys
sys.path.append('C:\\projects\\finances.git')

from finances.market import market_data as mkt_data

data_path = 'C:\\projects\\finances.git\\finances\\trading\\strategies\\dynamic_stoploss\\data'
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xb
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xb
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xb
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xc but this version of numpy is 0xb

# %%
def sharpe(data):
    return data.mean()/data.std()

# %% [markdown]
# # BTC

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_BTC_3.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='12H'].boxplot(
    column='strategy',
    by=['period','pct_gap', 'min_gain'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period', 'pct_gap', 'min_gain']).agg(sharpe)

# %%
fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['4H', '6H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n])
    ax[n].set_title(period)

# %% [markdown]
# ### Best performance:
# * Period: 8H
# * Pct Gap: 0.04
# * Min gain: 0.02

# %% [markdown]
# # ETH

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_ETH_3.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='8H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-10ac6d445425> in <module>()
# ----> 1 df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_ETH_3.csv'))
#       2
#       3 fig, ax = plt.subplots(1,1, figsize=(20,10))
#       4
#       5 df[df['period']=='8H'].boxplot(
#
# C:\Anaconda3\envs\finances\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# C:\Anaconda3\envs\finances\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# C:\Anaconda3\envs\finances\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# C:\Anaconda3\envs\finances\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# C:\Anaconda3\envs\finances\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'C:\\projects\\finances.git\\finances\\trading\\strategies\\dynamic_stoploss\\data\\dynamic_stoploss_strategy_ETH_3.csv' does not exist

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

# %%
fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['4H', '6H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n])
    ax[n].set_title(period)

# %% [markdown]
# #### Best performance:
# * Period: 4H
# * pct_gap = 0.035
# * minimum gain = 0.0475

# %% [markdown]
# # LTC

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_LTC_2.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='8H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['4H', '6H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n])
    ax[n].set_title(period)

# %% [markdown]
# #### Best performance:
# * Period: 4H
# * pct_gap = 0.025
# * minimum gain = 0.040

# %% [markdown]
# # XRP

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_XRP_2.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='4H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['4H', '6H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n])
    ax[n].set_title(period)

# %% [markdown]
# **Best configuration:**
#
# * Period: 8H
#
# * Pct Gap: 0.035
#
# * Minimum Gain: 0.025

# %% [markdown]
# # BCH

# %%
df = pd.read_csv(os.path.join(data_path, 'dynamic_stoploss_strategy_BCH_2.csv'))

fig, ax = plt.subplots(1,1, figsize=(20,10))

df[df['period']=='4H'].boxplot(
    column='strategy',
    by=['min_gain', 'pct_gap', 'period'],
    rot=90,
    ax=ax)
plt.tight_layout()
plt.show()

# %%
db = df.groupby(['period','min_gain', 'pct_gap']).agg(sharpe)

fig, ax = plt.subplots(1,4, figsize=(15,8), sharey=True)
for n, period in enumerate(['4H', '6H', '8H', '12H']):
    b = db.unstack(['period', 'pct_gap'])
    b['strategy'][period].plot(style='o-', ax=ax[n])
    ax[n].set_title(period)

# %% [markdown]
# **Best configuration:**
#
# * Period: 8H
#
# * Pct Gap: 0.025
#
# * Minimum Gain: 0.03
