# %%
# %matplotlib inline

import numpy as np
import statsmodels.api as sm
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import datetime

import sys
sys.path.append('C:\\projects\\finances.git\\finances')

from finances.market.market_data import MarketData
mkt = MarketData()
# Out:
# C:\Anaconda3\envs\finance\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Loaded crypto currency database from C:\projects\finances.git\finances\market\data_base\crypto_currencies\main_crypto_eur_database.csv

# %%
from portfolio.portfolio import PortFolio
# Out:
# Loaded crypto currency database from C:\projects\finances.git\finances\market\data_base\crypto_currencies\main_crypto_eur_database.csv

# %%
portfolio_assets = {
    'BTC': 0.007,
    'ETH': 2.14081,
    'XRP': 922.5,
    'ADA': 926,
    'XLM': 929.07,
    'LTC': 1.0,
    'TRX': 2760,
    'UBQ': 18.222,
    'BIS': 36.6,
    'IOTA': 47.553,
    'EMC2': 45,
    'FUN': 633.366,
    'ADST': 136.71
}

all_portfolio_assets = {
    'BTC': 0,
    'DASH': 0,
    'XMR': 0,
    'BCH': 0,
    'NEO': 0,
    'NEM': 0,
    'ETH': 0,
    'XRP': 0,
    'LTC': 0,
    'ADA': 0,
    'UBQ': 0,
    'BIS': 0,
    'IOTA': 0,
    'EMC2': 0,
    'TRX': 0,
    'FUN': 0,
    'XLM': 0
}

assets_effective_price = {
    'BTC': 0.1,
    'ETH': 454.96,
    'XRP': 0.772,
    'ADA': 0.404,
    'XLM': 0.378,
    'LTC': 208.23,
    'TRX': 0.0668,
    'UBQ': 5.7,
    'BIS': 3.48,
    'IOTA': 3.08,
    'EMC2': 0.769,
    'FUN': 0.0897,
    'ADST': 0.817   
}

# %%
import pylab as plt
import seaborn as sns
from pprint import pprint

sns.set()

myportfolio = PortFolio(
    name= 'PedroPortfolio'
    )
# Out:
# Loaded portfolio database from C:\projects\finances.git\finances\portfolio\PedroPortfolio\assets_allocation_data.csv

# %% [markdown]
# # Portfolio Comparison

# %%
myportfolio.assets_data
# Out:
#                 ADA    ADST  BCH        BIS       BTC      DASH  EMC2  \
# 2018-01-01  926.000  136.71  0.0  36.600000  0.007000  0.000000  45.0
# 2018-02-06    0.073  136.71  0.0  36.592335  0.080743  0.286593  45.0
#
#                 ETH       FUN    IOTA  LTC   NEO       TRX        UBQ     XLM  \
# 2018-01-01  2.14081   633.366  47.553  1.0  0.00  2760.000  18.222000  929.07
# 2018-02-06  2.14081  2550.366  47.553  1.5  2.04     0.237  18.222222  279.07
#
#                 XMR    XRP
# 2018-01-01  0.00000  922.5
# 2018-02-06  1.32867  130.0

# %% [markdown]
# ## Optimize the portfolio continuously

# %%
def apply_optimization(
    assets=all_portfolio_assets,
    start_date = datetime.datetime(2017,10,4),
    end_date = datetime.datetime.now(),
    update_frequency = 7
    ):

    time_delta = datetime.timedelta(days=update_frequency)
    time = start_date
    value = 100

    portfolio=PortFolio()
    portfolio.assets=assets
    while time<end_date:
        optimal_df = portfolio.optimize_allocation(
            projection_steps=update_frequency,
            date=time,
            value_to_invest=value)
        
        optimal_assets = optimal_df['coin_quantities'].to_dict()
# 2017-12-27  0.137416    0.000000  12.518710  0.278842   0.000000  0.000000
# 2018-01-03  0.118987    0.000000  11.225975  0.281209   0.000000  0.482691
# 2018-01-10  0.121777  328.747960   0.000000  0.314093   0.000000  0.515462
# 2018-01-17  0.098941    0.000000  15.629097  0.312584   0.000000  0.388114
# 2018-01-24  0.108822    0.000000   0.000000  0.343315   0.000000  0.469054
# 2018-01-31  0.090804    0.000000  15.815557  0.305071   0.000000  0.357483
# 2018-02-07  0.080774    0.000000  17.178556  0.296767   0.000000  0.366233
# 2018-02-14  0.081036    0.000000  16.696317  0.305821   0.000000  0.364936
# 2018-02-21  0.085210    0.000000  17.768455  0.249013   0.000000  0.371036
#
#                     TRX      UBQ         XLM       XMR        XRP
# 2017-10-04  4615.873693  4.36969  591.102112  0.079512  38.326278
# 2017-10-11     0.000000  0.00000  419.934914  0.000000  50.703052
# 2017-10-18     0.000000  0.00000    0.000000  0.000000  35.148448
# 2017-10-25  3068.592592  0.00000  255.251551  0.000000   0.000000
# 2017-11-01     0.000000  0.00000    0.000000  0.000000   0.000000
# 2017-11-08     0.000000  0.00000    0.000000  0.162497   0.000000
# 2017-11-15     0.000000  0.00000    0.000000  0.199964   0.000000
# 2017-11-22     0.000000  0.00000    0.000000  0.196402  59.462871
# 2017-11-29     0.000000  0.00000    0.000000  0.180790   0.000000
# 2017-12-06     0.000000  0.00000    0.000000  0.195531   0.000000
# 2017-12-13     0.000000  0.00000    0.000000  0.274743  88.113325
# 2017-12-20     0.000000  0.00000    0.000000  0.282805   0.000000
# 2017-12-27     0.000000  0.00000    0.000000  0.249806  33.131991
# 2018-01-03     0.000000  0.00000   55.923863  0.233744  16.590530
# 2018-01-10     0.000000  0.00000    0.000000  0.262147   0.000000
# 2018-01-17     0.000000  0.00000  103.744383  0.237130   0.000000
# 2018-01-24     0.000000  0.00000  103.699568  0.249491  30.269401
# 2018-01-31     0.000000  0.00000   90.545956  0.224820  30.463167
# 2018-02-07     0.000000  0.00000  105.573811  0.218073  35.767442
# 2018-02-14     0.000000  0.00000  100.109028  0.219329  30.893896
# 2018-02-21     0.000000  0.00000  112.575091  0.211862  32.645858

# %% [markdown]
# ### optimize only at the beginning

# %%
start_date = datetime.datetime(2017,11,3)
optimized_once_pfl = PortFolio()
optimized_once_pfl.assets = all_portfolio_assets

optimal_df = optimized_once_pfl.optimize_allocation(target_return=0.25, projection_steps=100, date=start_date, value_to_invest=100)
optimal_assets = optimal_df['coin_quantities'].to_dict()
optimized_once_pfl.insert_assets_at_date(assets=optimal_assets, date=start_date)
# Out:
#             ADA  BCH  BIS       BTC      DASH  EMC2     ETH  FUN  IOTA  \
# 2017-11-03  0.0  0.0  0.0  0.003328  0.085547   0.0  0.0646  0.0   0.0
#
#                  LTC        NEM  NEO  TRX  UBQ  XLM       XMR       XRP
# 2017-11-03  0.190722  59.802297  0.0  0.0  0.0  0.0  0.223568  40.08423

# %% [markdown]
# ### real one

# %%
myportfolio.insert_assets_at_date(assets=portfolio_assets, date=start_date)
myportfolio.update_data()

# %% [markdown]
# ### compare

# %%
fig = plt.figure(figsize=(15,10))

optimized_pfl.relative_variation_since(start_date=start_date)['TOTAL'].plot(label='optimal')
myportfolio.relative_variation_since(start_date=start_date)['TOTAL'].plot(label='regular')
optimized_once_pfl.relative_variation_since(start_date=start_date)['TOTAL'].plot(label='once')
plt.legend()

# %%
print(optimized_pfl.relative_variation_since(start_date=start_date)['TOTAL'].iloc[-1])
print(myportfolio.relative_variation_since(start_date=start_date)['TOTAL'].iloc[-1])
print(optimized_once_pfl.relative_variation_since(start_date=start_date)['TOTAL'].iloc[-1])
# Out:
# 1.93890100989
# 2.87273603601
# 1.64023672414

# %% [markdown]
# # Apply for random periods
#
# First apply to the all assets:

# %%
import random
fullrets = mkt.crypto_returns_data(
    symbols=list(all_portfolio_assets.keys())
    ).dropna()

time_delta_stress_test=datetime.timedelta(days=60)
fullrets.head()
# Out:
#                  BTC      DASH       XMR       BCH       NEO       NEM  \
# 2017-10-04 -0.023236  0.028149 -0.030237 -0.115701 -0.075569 -0.022062
# 2017-10-05  0.027342  0.003635  0.019932 -0.003729  0.039914 -0.030098
# 2017-10-06  0.012815  0.007850 -0.004326  0.023458  0.041518  0.004187
# 2017-10-07  0.012831  0.011764  0.005593 -0.006143  0.078162  0.004093
# 2017-10-08  0.041472 -0.025798 -0.021047 -0.051472 -0.112618 -0.081918
#
#                  ETH       XRP       LTC       ADA       UBQ       BIS  \
# 2017-10-04 -0.002203  0.053298 -0.020979  0.050526 -0.044431 -0.047987
# 2017-10-05  0.014808  0.107789  0.009105 -0.016399 -0.014873 -0.093852
# 2017-10-06  0.046145 -0.009608  0.011725 -0.134700 -0.003358  0.029681
# 2017-10-07  0.008199  0.019531  0.008826  0.129565 -0.063694  0.033948
# 2017-10-08 -0.008068  0.173228  0.010650 -0.022157 -0.142857 -0.254074
#
#                 IOTA      EMC2       TRX       FUN       XLM
# 2017-10-04 -0.029032 -0.118873  0.324326 -0.041141 -0.047262
# 2017-10-05 -0.007302 -0.085577  0.025453 -0.067997  0.234652
# 2017-10-06 -0.066483  0.178987 -0.094892 -0.026483  0.266330
# 2017-10-07  0.069681 -0.084889 -0.179239  0.000304  0.138890
# 2017-10-08 -0.071485 -0.082948  0.028874 -0.083438 -0.112649

# %%
return_sample=[]
for k in range(50):
    start_test = random.choice(fullrets.index)
    end_test=start_test+time_delta_stress_test
    pfl=apply_optimization(
        assets=all_portfolio_assets,
        start_date = start_test,
        end_date=end_test,
        update_frequency = 14
        )
    value=pfl.relative_variation_since(start_date=start_test)['TOTAL'].loc[:end_test]
    return_sample.append(value.iloc[-1])
    value.plot()

# %%
plt.boxplot(return_sample)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1a640df6b38>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a640e16630>,
#   <matplotlib.lines.Line2D at 0x1a640e16a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a640e1d390>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1a640e16ef0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1a640df6cc0>,
#   <matplotlib.lines.Line2D at 0x1a640e161d0>]}

# %% [markdown]
# ### Apply to selected portfolios

# %%
fullrets = mkt.crypto_returns_data(
    symbols=['BTC','LTC','XRP','ETH']
    ).dropna()

data_dict = {'optimal':[], 'raposas':[], 'eth':[], 'btc':[], 'ltc':[], 'xrp':[]}
assets_list_dict={
    'optimal':{'BTC':0, 'LTC':0, 'XRP':0, 'ETH':0},
    'raposas':{'XRP':1001, 'ETH':0.7},
    'eth':{'ETH':1},
    'btc': {'BTC':1},
    'ltc': {'LTC':1},
    'xrp': {'XRP':1}
    }

date_list = []

for k in range(50):
    start_test = random.choice(fullrets.index[fullrets.index>datetime.datetime(2016,6,1)])
    end_test=start_test+time_delta_stress_test
    date_list.append(start_test)
    
    for pfl in assets_list_dict:
        assets = assets_list_dict[pfl]
        if pfl=='optimal':
            portfolio=apply_optimization(
                assets=assets,
                start_date = start_test,
                end_date=end_test,
                update_frequency = 14
                )       
        else:
            portfolio=PortFolio()
            portfolio.insert_assets_at_date(assets=assets, date=start_test)
            portfolio.update_data()

        pfl_value=portfolio.relative_variation_since(start_date=start_test)['TOTAL'].loc[:end_test]
        data_dict[pfl].append(pfl_value.iloc[-1])

        
df = pd.DataFrame(index=date_list, data=data_dict)
# Out:
# 2017-09-30 00:00:00
# 2018-02-12 00:00:00
# 2017-12-19 00:00:00
# 2016-06-12 00:00:00
# 2018-01-05 00:00:00
# 2016-12-16 00:00:00
# 2016-07-05 00:00:00
# 2016-08-14 00:00:00
# 2017-04-27 00:00:00
# 2017-11-13 00:00:00
# 2017-12-05 00:00:00
# 2017-08-23 00:00:00
# 2017-06-06 00:00:00
# 2016-11-11 00:00:00
# 2016-08-22 00:00:00
# 2017-11-13 00:00:00
# 2017-06-14 00:00:00
# 2016-12-08 00:00:00
# 2016-11-18 00:00:00
# 2017-04-25 00:00:00
# 2016-10-02 00:00:00
# 2016-08-06 00:00:00
# 2018-01-19 00:00:00
# 2017-12-20 00:00:00
# 2016-12-18 00:00:00
# 2017-06-02 00:00:00
# 2017-03-04 00:00:00
# 2018-01-10 00:00:00
# 2017-12-26 00:00:00
# 2017-03-31 00:00:00
# 2017-03-09 00:00:00
# 2016-06-28 00:00:00
# 2018-01-25 00:00:00
# 2016-08-17 00:00:00
# 2017-10-24 00:00:00
# 2017-06-22 00:00:00
# 2017-04-18 00:00:00
# 2017-03-15 00:00:00
# 2016-09-18 00:00:00
# 2017-01-18 00:00:00
# 2017-11-01 00:00:00
# 2016-07-21 00:00:00
# 2017-02-26 00:00:00
# 2016-07-24 00:00:00
# 2016-08-25 00:00:00
# 2017-04-20 00:00:00
# 2017-11-26 00:00:00
# 2016-09-05 00:00:00
# 2017-03-22 00:00:00
# 2017-05-04 00:00:00

# %%
df.boxplot()
print(df.mean()/df.std())
plt.ylim(-1,4)
# Out:
# btc        0.637416
# eth        0.637943
# ltc        0.608835
# optimal    0.701478
# raposas    0.614284
# xrp        0.452530
# dtype: float64
# (-1, 4)
